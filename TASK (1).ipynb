# %% [markdown]
# # Function

# %% [markdown]
# 1.  What is a difference b/w a function and a method in python?
#
#     - jfvhjfkhfjfkgjbghhsjfhf
# 2.   second question IS VERY LONG ?
#      - DFDFFGGGN
